# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as plx
from pathlib import Path

# %%
period = 'daily'
market = 'us'

exchange = 'nasdaq'
partition = 2
ticker = 'msft'

pd.read_csv(f'data/stooq/{period}/{market}/{exchange} stocks/{partition}/{ticker}.{market}.txt')
# Out:
#      <TICKER> <PER>    <DATE>  <TIME>      <OPEN>      <HIGH>       <LOW>  \
# 0     MSFT.US     D  19860313       0    0.062951    0.070576    0.062951
# 1     MSFT.US     D  19860314       0    0.070576    0.070576    0.070576
# 2     MSFT.US     D  19860317       0    0.070576    0.070576    0.070576
# 3     MSFT.US     D  19860318       0    0.070576    0.070576    0.070576
# 4     MSFT.US     D  19860319       0    0.070576    0.070576    0.070576
# ...       ...   ...       ...     ...         ...         ...         ...
# 9625  MSFT.US     D  20240524       0  427.190000  431.055000  424.410000
# 9626  MSFT.US     D  20240528       0  429.630000  430.820000  426.600000
# 9627  MSFT.US     D  20240529       0  425.690000  430.940000  425.690000
# 9628  MSFT.US     D  20240530       0  424.300000  424.300000  414.240000
# 9629  MSFT.US     D  20240531       0  416.750000  416.750000  404.510000
#
#          <CLOSE>         <VOL>  <OPENINT>
# 0       0.070576  1.463519e+09          0
# 1       0.070576  4.371029e+08          0
# 2       0.070576  1.888938e+08          0
# 3       0.070576  9.612180e+07          0
# 4       0.070576  6.793478e+07          0
# ...          ...           ...        ...
# 9625  430.160000  1.185528e+07          0
# 9626  430.320000  1.571802e+07          0
# 9627  429.170000  1.551713e+07          0
# 9628  414.670000  2.842485e+07          0
# 9629  415.130000  4.799525e+07          0
#
# [9630 rows x 10 columns]

# %%
def load_table(path: Path) -> pd.DataFrame | None:
    try: 
        return pd.read_csv(path)
    except pd.errors.EmptyDataError:
        return None

# %%
pathes = Path(f'data/stooq/{period}/{market}').glob(f'* stocks/*/*.{market}.txt')
tables = [load_table(path) for path in pathes if path]

# %%
tables = pd.concat(tables)

# %%
tables.drop(columns=['<PER>', '<OPENINT>', '<TIME>'], inplace=True, errors='ignore')

# %%
tables['<DATE>'] = pd.to_datetime(tables['<DATE>'].astype(str))

# %%
tables
# Out:
#      <TICKER>     <DATE>    <OPEN>    <HIGH>     <LOW>   <CLOSE>  \
# 0      SAH.US 2005-02-25   20.5791   20.6557   20.4444   20.5859
# 1      SAH.US 2005-02-28   20.6193   20.6193   19.5078   19.6406
# 2      SAH.US 2005-03-01   19.7802   20.0552   19.7359   19.9040
# 3      SAH.US 2005-03-02   19.9040   20.1800   19.4814   19.8706
# 4      SAH.US 2005-03-03   19.9040   20.0002   19.6140   19.6769
# ...       ...        ...       ...       ...       ...       ...
# 4843  ANSS.US 2024-05-24  327.2500  333.6100  326.0700  331.1100
# 4844  ANSS.US 2024-05-28  328.4100  329.8250  325.8000  328.0800
# 4845  ANSS.US 2024-05-29  325.1500  326.9200  321.1000  322.4400
# 4846  ANSS.US 2024-05-30  320.8400  323.4100  319.5300  319.9100
# 4847  ANSS.US 2024-05-31  320.5100  320.8700  312.2700  317.4500
#
#               <VOL>
# 0     235572.034359
# 1     459954.119780
# 2     288780.261915
# 3     176818.696604
# 4     290593.693072
# ...             ...
# 4843  300299.000000
# 4844  466658.000000
# 4845  460218.000000
# 4846  366715.000000
# 4847  729944.000000
#
# [18454002 rows x 7 columns]

# %%
tables.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18454002 entries, 0 to 4847
# Data columns (total 7 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   <TICKER>  object
#  1   <DATE>    datetime64[ns]
#  2   <OPEN>    float64
#  3   <HIGH>    float64
#  4   <LOW>     float64
#  5   <CLOSE>   float64
#  6   <VOL>     float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 1.1+ GB

# %%
sample_companies = [
    'MSFT.US',
    'AVGO.US',
    'NVDA.US',
    'TSM.US',
    'TSLA.US',
    'META.US',
    'IBM.US',
    'AAPL.US',
    'ASML.US'
]

# %%
plx.line(
    data_frame=tables[tables['<TICKER>'].isin(sample_companies)], 
    x='<DATE>', 
    y='<CLOSE>', 
    color='<TICKER>',
    log_y=True,
)
